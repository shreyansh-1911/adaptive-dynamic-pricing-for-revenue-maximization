# %%
import pandas as pd

df = pd.read_csv("./US Airline Flight Routes and Fares 1993-2024.csv")  # folder name + file
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_29188\202805091.py:3: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./US Airline Flight Routes and Fares 1993-2024.csv")  # folder name + file
#        tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0  Table1a  2021        3           30135           33195
# 1  Table1a  2021        3           30135           33195
# 2  Table1a  2021        3           30140           30194
# 3  Table1a  2021        3           30140           30194
# 4  Table1a  2021        3           30140           30466
#
#                             city1                          city2  airportid_1  \
# 0  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 1  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 2                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# ...

# %%
df.drop(['tbl', 'citymarketid_1','citymarketid_2','airportid_1','airportid_2','Geocoded_City1','Geocoded_City2','tbl1apk'], axis=1, inplace=True)
df.head()
# Out:
#    Year  quarter                           city1  \
# 0  2021        3  Allentown/Bethlehem/Easton, PA
# 1  2021        3  Allentown/Bethlehem/Easton, PA
# 2  2021        3                 Albuquerque, NM
# 3  2021        3                 Albuquerque, NM
# 4  2021        3                 Albuquerque, NM
#
#                            city2 airport_1 airport_2  nsmiles  passengers  \
# 0  Tampa, FL (Metropolitan Area)       ABE       PIE      970         180
# 1  Tampa, FL (Metropolitan Area)       ABE       TPA      970          19
# 2          Dallas/Fort Worth, TX       ABQ       DAL      580         204
# 3          Dallas/Fort Worth, TX       ABQ       DFW      580         264
# 4                    Phoenix, AZ       ABQ       PHX      328         398
#
#      fare carrier_lg  large_ms  fare_lg carrier_low   lf_ms  fare_low
# 0   81.43         G4    1.0000    81.43          G4  1.0000     81.43
# 1  208.93         DL    0.4659   219.98          UA  0.1193    154.11
# ...

# %%
df.drop(['airport_1', 'airport_2'], axis=1, inplace=True)
df.head()
# Out:
#    Year  quarter                           city1  \
# 0  2021        3  Allentown/Bethlehem/Easton, PA
# 1  2021        3  Allentown/Bethlehem/Easton, PA
# 2  2021        3                 Albuquerque, NM
# 3  2021        3                 Albuquerque, NM
# 4  2021        3                 Albuquerque, NM
#
#                            city2  nsmiles  passengers    fare carrier_lg  \
# 0  Tampa, FL (Metropolitan Area)      970         180   81.43         G4
# 1  Tampa, FL (Metropolitan Area)      970          19  208.93         DL
# 2          Dallas/Fort Worth, TX      580         204  184.56         WN
# 3          Dallas/Fort Worth, TX      580         264  182.64         AA
# 4                    Phoenix, AZ      328         398  177.11         WN
#
#    large_ms  fare_lg carrier_low   lf_ms  fare_low
# 0    1.0000    81.43          G4  1.0000     81.43
# 1    0.4659   219.98          UA  0.1193    154.11
# 2    0.9968   184.44          WN  0.9968    184.44
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

#  Fare vs Passengers
axes[0].scatter(df['fare'], df['passengers'])
axes[0].set_xlabel("Fare")
axes[0].set_ylabel("Passengers")
axes[0].set_title("Fare vs Passengers")

# Fare vs Nsmiles
axes[1].scatter(df['fare'], df['nsmiles'])
axes[1].set_xlabel("Fare")
axes[1].set_ylabel("Nsmiles (Distance)")
axes[1].set_title("Fare vs Distance")

# Fare vs Large_ms
axes[2].scatter(df['fare'], df['large_ms'])
axes[2].set_xlabel("Fare")
axes[2].set_ylabel("Large Market Share")
axes[2].set_title("Fare vs Competition")

plt.tight_layout()
plt.show()

# %%
print(df[['fare', 'passengers', 'nsmiles', 'large_ms']].corr())
# Out:
#                 fare  passengers   nsmiles  large_ms
# fare        1.000000   -0.171460  0.500407 -0.182312
# passengers -0.171460    1.000000 -0.079008 -0.077901
# nsmiles     0.500407   -0.079008  1.000000 -0.400557
# large_ms   -0.182312   -0.077901 -0.400557  1.000000

# %%
# ✅ Create Route ID column
df['route_id'] = df['city1'] + "-" + df['city2']

# ✅ Average Competitor Fare column
df['avg_competitor_fare'] = (df['fare_lg'] + df['fare_low']) / 2

# ✅ Approx. Demand Index column
df['demand_index'] = df['passengers'] / df['nsmiles'].replace(0, pd.NA)
df['demand_index'] = df['demand_index'].fillna(0)

df.head()
# Out:
#    Year  quarter                           city1  \
# 0  2021        3  Allentown/Bethlehem/Easton, PA
# 1  2021        3  Allentown/Bethlehem/Easton, PA
# 2  2021        3                 Albuquerque, NM
# 3  2021        3                 Albuquerque, NM
# 4  2021        3                 Albuquerque, NM
#
#                            city2  nsmiles  passengers    fare carrier_lg  \
# 0  Tampa, FL (Metropolitan Area)      970         180   81.43         G4
# 1  Tampa, FL (Metropolitan Area)      970          19  208.93         DL
# 2          Dallas/Fort Worth, TX      580         204  184.56         WN
# 3          Dallas/Fort Worth, TX      580         264  182.64         AA
# 4                    Phoenix, AZ      328         398  177.11         WN
#
#    large_ms  fare_lg carrier_low   lf_ms  fare_low  \
# 0    1.0000    81.43          G4  1.0000     81.43
# 1    0.4659   219.98          UA  0.1193    154.11
# 2    0.9968   184.44          WN  0.9968    184.44
# ...

# %%
yearly_fare = df.groupby('Year')['fare'].mean().reset_index()
yearly_fare
# Out:
#     Year        fare
# 0   1993  214.472632
# 1   1994  217.611944
# 2   1996  204.900283
# 3   1997  208.105858
# 4   1998  210.451983
# 5   1999  209.815562
# 6   2000  218.794348
# 7   2001  200.860409
# 8   2002  193.810930
# 9   2003  197.277303
# 10  2004  189.021593
# 11  2005  186.991831
# 12  2006  205.197657
# 13  2007  202.886365
# 14  2008  220.254945
# 15  2009  195.406621
# 16  2010  213.119534
# 17  2011  232.018487
# 18  2012  241.111118
# 19  2013  244.911938
# 20  2014  251.657087
# 21  2015  247.992015
# 22  2016  240.550512
# 23  2017  240.096521
# 24  2018  239.809121
# 25  2019  241.179140
# 26  2020  193.615156
# 27  2021  206.346408
# 28  2022  249.667511
# 29  2023  249.931843
# 30  2024  257.243160

# %%
plt.figure(figsize=(8,5))
plt.bar(yearly_fare['Year'], yearly_fare['fare'])
plt.xlabel("Year")
plt.ylabel("Average Fare")
plt.title("Year-wise Average Fare")
plt.show()
